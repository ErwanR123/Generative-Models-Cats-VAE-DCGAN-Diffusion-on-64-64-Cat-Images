# %%
# Reload the model (for testing or inference)
model_loaded = VAE(latent_dim=128).to(device)
model_loaded.load_state_dict(torch.load("vae_cats.pth", map_location=device))
model_loaded.eval()

print("Model reloaded successfully.")
